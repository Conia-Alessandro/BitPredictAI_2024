# %%
import pandas as pd

# %%
df = pd.read_csv("btc-usd-max-EDITED-FOR-2018NOV.csv")
bf = pd.read_csv("btc-usd-max-EDITED-FOR-2018NOV.csv")

# %%
df = df.interpolate(method ='linear', limit_direction ='forward')
# Out:
# C:\Users\Daan\AppData\Local\Temp\ipykernel_34984\1145945141.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df = df.interpolate(method ='linear', limit_direction ='forward')

# %%
print(df.loc[[2017]])
print(df.loc[[2018]])
print(df.loc[[2019]])
print(df.loc[[2020]])
print(df.loc[[2021]])
print(df.loc[[2022]])
print(df.loc[[2023]])
print(df.loc[[2024]])
print(df.loc[[2025]])
print(df.loc[[2026]])
print(df.loc[[2027]])
print(df.loc[[2028]])
print(df.loc[[2029]])
print(df.loc[[2030]])
print(df.loc[[2031]])
print(df.loc[[2032]])
print(df.loc[[2033]])
print(df.loc[[2034]])
print(df.loc[[2035]])
print(df.loc[[2036]])
print(df.loc[[2037]])
print(df.loc[[2038]])
print(df.loc[[2039]])
print(df.loc[[2040]])
print(df.loc[[2041]])
print(df.loc[[2042]])
print(df.loc[[2043]])
print(df.loc[[2044]])
print(df.loc[[2045]])
print(df.loc[[2046]])
print(df.loc[[2047]])
print(df.loc[[2048]])
print(df.loc[[2049]])
print(df.loc[[2050]])
print(df.loc[[2051]])
print(df.loc[[2052]])
print(df.loc[[2053]])
print(df.loc[[2054]])
print(df.loc[[2055]])
print(df.loc[[2056]])
print(df.loc[[2057]])
print(df.loc[[2058]])
print(df.loc[[2059]])
print(df.loc[[2060]])
print(df.loc[[2061]])
print(df.loc[[2062]])
print(df.loc[[2063]])
print(df.loc[[2064]])
print(df.loc[[2065]])
print(df.loc[[2066]])
print(df.loc[[2067]])
print(df.loc[[2068]])
print(df.loc[[2069]])
print(df.loc[[2070]])
# Out:
#                    snapped_at        price    market_cap  total_volume
# 2017  2018-11-07 00:00:00 UTC  6033.801942  1.047571e+11  2.078412e+09
#                    snapped_at       price    market_cap  total_volume
# 2018  2018-11-08 00:00:00 UTC  5991.23339  1.040237e+11  2.095012e+09
#                    snapped_at        price    market_cap  total_volume
# 2019  2018-11-09 00:00:00 UTC  5948.664837  1.032904e+11  2.111612e+09
#                    snapped_at        price    market_cap  total_volume
# 2020  2018-11-10 00:00:00 UTC  5906.096285  1.025570e+11  2.128213e+09
#                    snapped_at        price    market_cap  total_volume
# 2021  2018-11-11 00:00:00 UTC  5863.527733  1.018237e+11  2.144813e+09
#                    snapped_at       price    market_cap  total_volume
# 2022  2018-11-12 00:00:00 UTC  5820.95918  1.010903e+11  2.161413e+09
#                    snapped_at        price    market_cap  total_volume
# ...

# %%
print(bf.loc[[2018]])
print(bf.loc[[2019]])
print(bf.loc[[2020]])
print(bf.loc[[2021]])
print(bf.loc[[2022]])
print(bf.loc[[2023]])
print(bf.loc[[2024]])
print(bf.loc[[2025]])
print(bf.loc[[2026]])
print(bf.loc[[2027]])
print(bf.loc[[2028]])
print(bf.loc[[2029]])
print(bf.loc[[2030]])
print(bf.loc[[2031]])
print(bf.loc[[2032]])
print(bf.loc[[2033]])
print(bf.loc[[2034]])
print(bf.loc[[2035]])
print(bf.loc[[2036]])
print(bf.loc[[2037]])
print(bf.loc[[2038]])
print(bf.loc[[2039]])
print(bf.loc[[2040]])
print(bf.loc[[2041]])
print(bf.loc[[2042]])
print(bf.loc[[2043]])
print(bf.loc[[2044]])
print(bf.loc[[2045]])
print(bf.loc[[2046]])
print(bf.loc[[2047]])
print(bf.loc[[2048]])
print(bf.loc[[2049]])
print(bf.loc[[2050]])
print(bf.loc[[2051]])
print(bf.loc[[2052]])
print(bf.loc[[2053]])
print(bf.loc[[2054]])
print(bf.loc[[2055]])
print(bf.loc[[2056]])
print(bf.loc[[2057]])
print(bf.loc[[2058]])
print(bf.loc[[2059]])
print(bf.loc[[2060]])
print(bf.loc[[2061]])
print(bf.loc[[2062]])
print(bf.loc[[2063]])
print(bf.loc[[2064]])
print(bf.loc[[2065]])
print(bf.loc[[2066]])
print(bf.loc[[2067]])
print(bf.loc[[2068]])
print(bf.loc[[2069]])
print(bf.loc[[2070]])
print(bf.loc[[2071]])
print(bf.loc[[2072]])
print(bf.loc[[2073]])
print(bf.loc[[2074]])
# Out:
#                    snapped_at  price  market_cap  total_volume
# 2018  2018-11-08 00:00:00 UTC    NaN         NaN           NaN
#                    snapped_at  price  market_cap  total_volume
# 2019  2018-11-09 00:00:00 UTC    NaN         NaN           NaN
#                    snapped_at  price  market_cap  total_volume
# 2020  2018-11-10 00:00:00 UTC    NaN         NaN           NaN
#                    snapped_at  price  market_cap  total_volume
# 2021  2018-11-11 00:00:00 UTC    NaN         NaN           NaN
#                    snapped_at  price  market_cap  total_volume
# 2022  2018-11-12 00:00:00 UTC    NaN         NaN           NaN
#                    snapped_at  price  market_cap  total_volume
# 2023  2018-11-13 00:00:00 UTC    NaN         NaN           NaN
#                    snapped_at  price  market_cap  total_volume
# 2024  2018-11-14 00:00:00 UTC    NaN         NaN           NaN
#                    snapped_at  price  market_cap  total_volume
# ...
